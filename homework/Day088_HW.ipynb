# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix

# Record_fp_tp
class Record_tp_tn(Callback):
    """Code Here
    撰寫一個紀錄 true positive 與 true negative 數量的 callbacks    
    """
    
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].ravel()
        y_pred = self.model.predict(self.validation_data[0]).ravel()
        y_pred = (y_pred >= thres) * 1
        print(confusion_matrix(y_true,y_pred).ravel())
        (tn, fp, fn, tp) = confusion_matrix(y_true,y_pred).ravel()
        logs["val_tp"] = tp
        logs["val_tn"] = tn

rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train,
         epochs=EPOCHS,
         batch_size=BATCH_SIZE,
         validation_data=(x_test,y_test),
         shuffle=True,
         callbacks=[rec_tptn]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 2.2527 - accuracy: 0.2596 - val_loss: 2.1501 - val_accuracy: 0.1753
# [89998     2  9998     2]
# Epoch 2/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.7727 - accuracy: 0.3845 - val_loss: 1.9900 - val_accuracy: 0.2856
# [89982    18  9927    73]
# Epoch 3/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.6439 - accuracy: 0.4246 - val_loss: 1.8480 - val_accuracy: 0.3685
# [89934    66  9751   249]
# Epoch 4/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.5687 - accuracy: 0.4496 - val_loss: 1.7428 - val_accuracy: 0.3973
# [89797   203  9366   634]
# Epoch 5/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.5156 - accuracy: 0.4672 - val_loss: 1.6489 - val_accuracy: 0.4274
# [89575   425  8817  1183]
# Epoch 6/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.4709 - accuracy: 0.4834 - val_loss: 1.5855 - val_accuracy: 0.4469
# [89405   595  8411  1589]
# Epoch 7/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.4348 - accuracy: 0.4975 - val_loss: 1.5494 - val_accuracy: 0.4593
# [89110   890  7962  2038]
# Epoch 8/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.4015 - accuracy: 0.5094 - val_loss: 1.5383 - val_accuracy: 0.4555
# [89023   977  7895  2105]
# Epoch 9/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.3729 - accuracy: 0.5192 - val_loss: 1.5066 - val_accuracy: 0.4672
# [88815  1185  7558  2442]
# Epoch 10/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.3443 - accuracy: 0.5296 - val_loss: 1.5054 - val_accuracy: 0.4695
# [88654  1346  7356  2644]
# Epoch 11/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.3196 - accuracy: 0.5397 - val_loss: 1.4837 - val_accuracy: 0.4759
# [88623  1377  7245  2755]
# Epoch 12/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.2959 - accuracy: 0.5487 - val_loss: 1.4891 - val_accuracy: 0.4757
# [88531  1469  7153  2847]
# Epoch 13/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.2717 - accuracy: 0.5586 - val_loss: 1.4719 - val_accuracy: 0.4791
# [88534  1466  7096  2904]
# Epoch 14/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.2504 - accuracy: 0.5652 - val_loss: 1.4670 - val_accuracy: 0.4895
# [88439  1561  6965  3035]
# Epoch 15/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.2299 - accuracy: 0.5746 - val_loss: 1.4602 - val_accuracy: 0.4855
# [88443  1557  6967  3033]
# Epoch 16/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.2084 - accuracy: 0.5806 - val_loss: 1.4484 - val_accuracy: 0.4940
# [88428  1572  6851  3149]
# Epoch 17/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.1893 - accuracy: 0.5892 - val_loss: 1.4474 - val_accuracy: 0.4940
# [88324  1676  6753  3247]
# Epoch 18/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.1698 - accuracy: 0.5943 - val_loss: 1.4601 - val_accuracy: 0.4864
# [88206  1794  6696  3304]
# Epoch 19/25
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.1515 - accuracy: 0.6032 - val_loss: 1.4405 - val_accuracy: 0.4939
# [88303  1697  6761  3239]
# Epoch 20/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.1343 - accuracy: 0.6094 - val_loss: 1.4529 - val_accuracy: 0.4936
# [88272  1728  6739  3261]
# Epoch 21/25
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.1164 - accuracy: 0.6163 - val_loss: 1.4504 - val_accuracy: 0.4929
# [88152  1848  6611  3389]
# Epoch 22/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.0983 - accuracy: 0.6229 - val_loss: 1.4386 - val_accuracy: 0.4960
# [88106  1894  6560  3440]
# Epoch 23/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.0819 - accuracy: 0.6287 - val_loss: 1.4434 - val_accuracy: 0.4964
# [88142  1858  6581  3419]
# Epoch 24/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.0648 - accuracy: 0.6350 - val_loss: 1.4399 - val_accuracy: 0.4983
# [88102  1898  6535  3465]
# Epoch 25/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.0499 - accuracy: 0.6415 - val_loss: 1.4461 - val_accuracy: 0.4971
# [88083  1917  6543  3457]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.xlabel('Epochs')
plt.ylabel('Number of TP')
plt.title("True positives")

plt.figure(figsize=(12,8))
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Number of TN')
plt.title("True Negatives")
# Out:
# Text(0.5, 1.0, 'True Negatives')
